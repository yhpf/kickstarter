# %% [markdown]
# # Kickstarter

# %% [markdown]
# What will make your project at Kickstarter successful?

# %% [markdown]
# ## Import stuff

# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight')

# %matplotlib inline

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('./DSI_kickstarterscrape_dataset.csv')

# %% [markdown]
# ## Look at the data

# %% [markdown]
# Take an initial look at the data and especially the columns

# %%
data.head(3)
# Out:
#    project id                                  name  \
# 0       39409                 WHILE THE TREES SLEEP
# 1      126581  Educational Online Trading Card Game
# 2      138119                                 STRUM
#
#                                                  url      category  \
# 0  http://www.kickstarter.com/projects/emiliesaba...  Film & Video
# 1  http://www.kickstarter.com/projects/972789543/...         Games
# 2  http://www.kickstarter.com/projects/185476022/...  Film & Video
#
#           subcategory         location      status     goal  pledged  \
# 0          Short Film     Columbia, MO  successful  10500.0  11545.0
# 1  Board & Card Games    Maplewood, NJ      failed   4000.0     20.0
# 2           Animation  Los Angeles, CA        live  20000.0     56.0
#
#    funded percentage  backers                      funded date  levels  \
# 0           1.099524       66  Fri, 19 Aug 2011 19:28:17 -0000       7
# 1           0.005000        2  Mon, 02 Aug 2010 03:59:00 -0000       5
# 2           0.002800        3  Fri, 08 Jun 2012 00:00:31 -0000      10
#
#                                        reward levels  updates  comments  \
# 0               $25,$50,$100,$250,$500,$1,000,$2,500       10         2
# 1                                  $1,$5,$10,$25,$50        6         0
# 2  $1,$10,$25,$40,$50,$100,$250,$1,000,$1,337,$9,001        1         0
#
#    duration
# 0     30.00
# 1     47.18
# 2     28.00

# %% [markdown]
# How many rows and columns

# %%
data.shape
# Out:
# (45957, 17)

# %% [markdown]
# Get more info about the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45957 entries, 0 to 45956
# Data columns (total 17 columns):
# project id           45957 non-null int64
# name                 45957 non-null object
# url                  45957 non-null object
# category             45957 non-null object
# subcategory          45957 non-null object
# location             44635 non-null object
# status               45957 non-null object
# goal                 45957 non-null float64
# pledged              45945 non-null float64
# funded percentage    45957 non-null float64
# backers              45957 non-null int64
# funded date          45957 non-null object
# levels               45957 non-null int64
# reward levels        45898 non-null object
# updates              45957 non-null int64
# comments             45957 non-null int64
# duration             45957 non-null float64
# dtypes: float64(4), int64(5), object(8)
# memory usage: 6.0+ MB

# %% [markdown]
# Get more info about missing data

# %%
data.isnull().sum()
# Out:
# project id              0
# name                    0
# url                     0
# category                0
# subcategory             0
# location             1322
# status                  0
# goal                    0
# pledged                12
# funded percentage       0
# backers                 0
# funded date             0
# levels                  0
# reward levels          59
# updates                 0
# comments                0
# duration                0
# dtype: int64

# %% [markdown]
# Look for duplicates

# %%
data.duplicated().sum()
# Out:
# 89

# %% [markdown]
# Get statistical info about the data (might need to be redone after other things are fixed with the data). Here we can also see signs of outliers.

# %%
data.describe()
# Out:
#          project id          goal       pledged  funded percentage  \
# count  4.595700e+04  4.595700e+04  4.594500e+04       45957.000000
# mean   1.080800e+09  1.194271e+04  4.980750e+03           1.850129
# std    6.218057e+08  1.887583e+05  5.674162e+04          88.492706
# min    3.940900e+04  1.000000e-02  0.000000e+00           0.000000
# 25%    5.438962e+08  1.800000e+03  1.960000e+02           0.044000
# 50%    1.078345e+09  4.000000e+03  1.310000e+03           1.000000
# 75%    1.621596e+09  9.862000e+03  4.165000e+03           1.115640
# max    2.147460e+09  2.147484e+07  1.026684e+07       15066.000000
#
#             backers        levels      updates      comments      duration
# count  45957.000000  45957.000000  45957.00000  45957.000000  45957.000000
# mean      69.973192      8.004939      4.08508      8.379529     39.995547
# std      688.628479      4.233907      6.43922    174.015737     17.414458
# min        0.000000      0.000000      0.00000      0.000000      1.000000
# 25%        5.000000      5.000000      0.00000      0.000000     30.000000
# 50%       23.000000      7.000000      2.00000      0.000000     32.000000
# 75%       59.000000     10.000000      6.00000      3.000000     48.390000
# max    87142.000000     80.000000    149.00000  19311.000000     91.960000

# %% [markdown]
# ### What I need to fix

# %% [markdown]
# - Category column: Make dummies out of categories
# - Subcategory column: Make dummies out of subcategories
# - Location column: Split into 2 new columns (city and state) - make dummies?
# - Status column: Give the status numbers. (1 = successful, 2 = failed, 3 = live)
# - Funded date column: Make into date time format
# - Reward levels column: Make numeric
#
#
# Handle missing values.<BR/>
# Look for duplicates.<BR/>
# Look for outliers.<BR/>
# ...

# %% [markdown]
# ## Work the data (EDA/Munging)

# %% [markdown]
# ### Duplicates

# %% [markdown]
# #### Handle

# %% [markdown]
# ### Missing values

# %% [markdown]
# ### funded date column: Split column into different columns

# %%
data['funded date'].head()
# Out:
# 0    Fri, 19 Aug 2011 19:28:17 -0000
# 1    Mon, 02 Aug 2010 03:59:00 -0000
# 2    Fri, 08 Jun 2012 00:00:31 -0000
# 3    Sun, 08 Apr 2012 02:14:00 -0000
# 4    Wed, 01 Jun 2011 15:25:39 -0000
# Name: funded date, dtype: object

# %%
new_date = data['funded date'].str.split(", ", n=1, expand=True)
data["weekday"]= new_date[0] 
data["date"]= new_date[1]

# %%
new_date2 = data['date'].str.split(" ", n=1, expand=True)
data["nr_in_month"]= new_date2[0] 
data["date2"]= new_date2[1]

# %%
new_date3 = data['date2'].str.split(" ", n=1, expand=True)
data["month"]= new_date3[0] 
data["date3"]= new_date3[1]

# %%
new_date4 = data['date3'].str.split(" ", n=1, expand=True)
data["year"]= new_date4[0] 
data["time"]= new_date4[1]

# %%
# remove columns not needed
data = data.drop(['date', 'date2', 'date3'], axis=1)
data.head(3)
# Out:
#    project id                                  name  \
# 0       39409                 WHILE THE TREES SLEEP
# 1      126581  Educational Online Trading Card Game
# 2      138119                                 STRUM
#
#                                                  url      category  \
# 0  http://www.kickstarter.com/projects/emiliesaba...  Film & Video
# 1  http://www.kickstarter.com/projects/972789543/...         Games
# 2  http://www.kickstarter.com/projects/185476022/...  Film & Video
#
#           subcategory         location      status     goal  pledged  \
# 0          Short Film     Columbia, MO  successful  10500.0  11545.0
# 1  Board & Card Games    Maplewood, NJ      failed   4000.0     20.0
# 2           Animation  Los Angeles, CA        live  20000.0     56.0
#
#    funded percentage       ...        levels  \
# 0           1.099524       ...             7
# 1           0.005000       ...             5
# 2           0.002800       ...            10
#
#                                        reward levels  updates comments  \
# 0               $25,$50,$100,$250,$500,$1,000,$2,500       10        2
# 1                                  $1,$5,$10,$25,$50        6        0
# 2  $1,$10,$25,$40,$50,$100,$250,$1,000,$1,337,$9,001        1        0
#
#    duration  weekday  nr_in_month month  year            time
# 0     30.00      Fri           19   Aug  2011  19:28:17 -0000
# 1     47.18      Mon           02   Aug  2010  03:59:00 -0000
# 2     28.00      Fri           08   Jun  2012  00:00:31 -0000
#
# [3 rows x 22 columns]

# %%
### Make day column to number (1 = monday, 2 = tuesday etc.)
data['weekday_nr'] = data['weekday'].replace({'Mon': 1, 'Tue': 2, 'Wed': 3, 'Thu': 4, 'Fri': 5, 'Sat': 6, 'Sun':7})

# %%
### Make month column to number (1 = jan, 2 = feb etc.)
data['month_nr'] = data['month'].replace({'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6, 'Jul':7,
                                             'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12})

# %%
data.head()
# Out:
#    project id                                               name  \
# 0       39409                              WHILE THE TREES SLEEP
# 1      126581               Educational Online Trading Card Game
# 2      138119                                              STRUM
# 3      237090  GETTING OVER - One son's search to finally kno...
# 4      246101  The Launch of FlyeGrlRoyalty &quot;The New Nam...
#
#                                                  url      category  \
# 0  http://www.kickstarter.com/projects/emiliesaba...  Film & Video
# 1  http://www.kickstarter.com/projects/972789543/...         Games
# 2  http://www.kickstarter.com/projects/185476022/...  Film & Video
# 3  http://www.kickstarter.com/projects/charnick/g...  Film & Video
# 4  http://www.kickstarter.com/projects/flyegrlroy...       Fashion
#
#           subcategory         location      status     goal  pledged  \
# 0          Short Film     Columbia, MO  successful  10500.0  11545.0
# 1  Board & Card Games    Maplewood, NJ      failed   4000.0     20.0
# 2           Animation  Los Angeles, CA        live  20000.0     56.0
# 3         Documentary  Los Angeles, CA  successful   6000.0   6535.0
# 4             Fashion         Novi, MI      failed   3500.0      0.0
#
#    funded percentage   ...     updates comments  duration weekday  \
# 0           1.099524   ...          10        2     30.00     Fri
# 1           0.005000   ...           6        0     47.18     Mon
# 2           0.002800   ...           1        0     28.00     Fri
# 3           1.089167   ...           4        0     32.22     Sun
# 4           0.000000   ...           2        0     30.00     Wed
#
#    nr_in_month  month  year            time weekday_nr month_nr
# 0           19    Aug  2011  19:28:17 -0000          5        8
# 1           02    Aug  2010  03:59:00 -0000          1        8
# 2           08    Jun  2012  00:00:31 -0000          5        6
# 3           08    Apr  2012  02:14:00 -0000          7        4
# 4           01    Jun  2011  15:25:39 -0000          3        6
#
# [5 rows x 24 columns]

# %%
data[['project id', 'name', 'url', 'category', 'subcategory', 'location', 'status', 'goal', 'pledged', 
             'funded percentage', 'reward levels', 'updates', 'comments', 'duration', 'weekday', 'weekday_nr', 
             'month', 'month_nr', 'year', 'time']]
# Out:
#        project id                                               name  \
# 0           39409                              WHILE THE TREES SLEEP
# 1          126581               Educational Online Trading Card Game
# 2          138119                                              STRUM
# 3          237090  GETTING OVER - One son's search to finally kno...
# 4          246101  The Launch of FlyeGrlRoyalty &quot;The New Nam...
# 5          316217  Dinner Party - a short film about friendship.....
# 6          325034                                              Mezzo
# 7          407836  Help APORTA continue to make handwoven/knit ac...
# 8          436325                            Music - Comedy - Album!
# 9          610918                            The Apocalypse Calendar
# 10         710161  It's You Again - A new comedy show (and short ...
# 11         727286                       Offline Wikipedia iPhone app
# 12         735377                       The Janks music video series
# 13         868003     Adam Barruch Dance: 2011 New York Performances
# 14         893085                            Esperanza Farm: A Novel
# 15         958158                                           GGS Film
# 16        1057236                 The Life and Adventures of Sue Bee
# 17        1122138              Summit City - Self Publishing Project
# 18        1163007                          LAST TOUCHES TO ALL NIGHT
# 19        1167521  Spots the Space Marine: Military SF for the Re...
# 20        1188601                                  The Doctor is Out
# 21        1251688                         Humerus - Independent Film
# 22        1253029               Release Sxip Shirey's SONIC NEW YORK
# 23        1349658                  RISUS Free Adventure Project 2012
# 24        1352667                                  Musical Note Dice
# 25        1380209            Crossroads [San Francisco Cinematheque]
# 26        1397716  &quot;Misfits of Love&quot; a book of art and ...
# 27        1497280                     Help DRC create FuturePatrons!
# 28        1505845                                       Homeless Cop
# 29        1512678  Eyes and Ears on English - comedy/English educ...
# ...           ...                                                ...
# 45927  2146319054                             Onipa`a (Be Steadfast)
# 45928  2146319054                             Onipa`a (Be Steadfast)
# 45929  2146435917  Making Mama(s) Proud: The 2011 &quot;Donna/Mad...
# 45930  2146435917  Making Mama(s) Proud: The 2011 &quot;Donna/Mad...
# 45931  2146437406                          The Production of Erasure
# 45932  2146437406                          The Production of Erasure
# 45933  2146534146             CALLING on ANGELS - not FOR KIDS ONLY!
# 45934  2146534146             CALLING on ANGELS - not FOR KIDS ONLY!
# 45935  2146600489  Riddle of the Black Cat, animated short based ...
# 45936  2146658173  The Best Little Sweet Shop in Vegas: Naked Cit...
# 45937  2146662513  &quot;My Life on Spec&quot; - Film on &quot;Si...
# 45938  2146667244                            Thank You For Seeing Me
# 45939  2146712016                        Hogo Cabernet: A Fine Swine
# 45940  2146782499     100 PAINTINGS 100 DAYS: Limited Edition Prints
# 45941  2146802059                           Good Afternoon, Miss Moo
# 45942  2146902905           Eco-Friendly Modern Luxury Pet Furniture
# 45943  2146955875                        GMO Film Project (Untitled)
# 45944  2146970878                                    HAPPINESS COMIX
# 45945  2146996147                    Make an album with American Gun
# 45946  2147024839       Artistic View of High School Sports Calendar
# 45947  2147049744                         The Velvet Painting Series
# 45948  2147063427                            Pumpkin Morgue Series 2
# 45949  2147078619  The Hayloft Gang: The Story of the National Ba...
# 45950  2147195890  Baseball, Dennis &amp; The French:  Dennis Prager
# 45951  2147219671  You Are Among Friends: a book for the little s...
# 45952  2147336747                                  The Dance Project
# 45953  2147346811  new album from J-Sw!ft The Adventures of Negro...
# 45954  2147367534                                      ELIZABETH REX
# 45955  2147369705                     Dragon Keepers IV Book Project
# 45956  2147460119                                 Moments of Insight
#
#                                                      url          category  \
# 0      http://www.kickstarter.com/projects/emiliesaba...      Film & Video
# 1      http://www.kickstarter.com/projects/972789543/...             Games
# 2      http://www.kickstarter.com/projects/185476022/...      Film & Video
# 3      http://www.kickstarter.com/projects/charnick/g...      Film & Video
# 4      http://www.kickstarter.com/projects/flyegrlroy...           Fashion
# 5      http://www.kickstarter.com/projects/249354515/...      Film & Video
# 6      http://www.kickstarter.com/projects/geoffsaysh...      Film & Video
# 7      http://www.kickstarter.com/projects/1078097864...           Fashion
# 8      http://www.kickstarter.com/projects/mattgriffo...             Music
# 9      http://www.kickstarter.com/projects/tqvinn/the...               Art
# 10     http://www.kickstarter.com/projects/657780861/...      Film & Video
# 11     http://www.kickstarter.com/projects/dphiffer/o...        Technology
# 12     http://www.kickstarter.com/projects/thejanks/t...             Music
# 13     http://www.kickstarter.com/projects/368421317/...             Dance
# 14     http://www.kickstarter.com/projects/JesusMaria...        Publishing
# 15     http://www.kickstarter.com/projects/2081504493...      Film & Video
# 16     http://www.kickstarter.com/projects/2054420885...        Publishing
# 17     http://www.kickstarter.com/projects/1314770525...        Publishing
# 18     http://www.kickstarter.com/projects/1131482096...      Film & Video
# 19     http://www.kickstarter.com/projects/mcahogarth...        Publishing
# 20     http://www.kickstarter.com/projects/2074346944...           Theater
# 21     http://www.kickstarter.com/projects/satmary/hu...      Film & Video
# 22     http://www.kickstarter.com/projects/sxipshirey...             Music
# 23     http://www.kickstarter.com/projects/sjohnross/...             Games
# 24     http://www.kickstarter.com/projects/1062097493...             Games
# 25     http://www.kickstarter.com/projects/1009133526...      Film & Video
# 26     http://www.kickstarter.com/projects/katherined...        Publishing
# 27     http://www.kickstarter.com/projects/122766416/...           Theater
# 28     http://www.kickstarter.com/projects/doejo/home...      Film & Video
# 29     http://www.kickstarter.com/projects/1787808582...      Film & Video
# ...                                                  ...               ...
# 45927  http://www.kickstarter.com/projects/1223795292...  Film &amp; Video
# 45928  http://www.kickstarter.com/projects/1223795292...      Film & Video
# 45929  http://www.kickstarter.com/projects/johnpaulka...           Theater
# 45930  http://www.kickstarter.com/projects/johnpaulka...           Theater
# 45931  http://www.kickstarter.com/projects/295025953/...       Photography
# 45932  http://www.kickstarter.com/projects/295025953/...       Photography
# 45933  http://www.kickstarter.com/projects/callingona...  Film &amp; Video
# 45934  http://www.kickstarter.com/projects/callingona...      Film & Video
# 45935  http://www.kickstarter.com/projects/1932594329...  Film &amp; Video
# 45936  http://www.kickstarter.com/projects/781435581/...              Food
# 45937  http://www.kickstarter.com/projects/1115287454...  Film &amp; Video
# 45938  http://www.kickstarter.com/projects/onefeather...           Fashion
# 45939  http://www.kickstarter.com/projects/548135915/...               Art
# 45940  http://www.kickstarter.com/projects/614978966/...               Art
# 45941  http://www.kickstarter.com/projects/1914500078...        Publishing
# 45942  http://www.kickstarter.com/projects/petlounges...            Design
# 45943  http://www.kickstarter.com/projects/gmofilmpro...  Film &amp; Video
# 45944  http://www.kickstarter.com/projects/1330417232...            Comics
# 45945  http://www.kickstarter.com/projects/1632062336...             Music
# 45946  http://www.kickstarter.com/projects/623412368/...       Photography
# 45947  http://www.kickstarter.com/projects/jirard/the...       Photography
# 45948  http://www.kickstarter.com/projects/353619240/...  Film &amp; Video
# 45949  http://www.kickstarter.com/projects/163043958/...  Film &amp; Video
# 45950  http://www.kickstarter.com/projects/1853714396...  Film &amp; Video
# 45951  http://www.kickstarter.com/projects/1877936423...        Publishing
# 45952  http://www.kickstarter.com/projects/685772205/...             Dance
# 45953  http://www.kickstarter.com/projects/170926480/...             Music
# 45954  http://www.kickstarter.com/projects/elizabethr...             Music
# 45955  http://www.kickstarter.com/projects/brucegoldw...        Publishing
# 45956  http://www.kickstarter.com/projects/1743305220...               Art
#
#               subcategory           location      status     goal  pledged  \
# 0              Short Film       Columbia, MO  successful  10500.0  11545.0
# 1      Board & Card Games      Maplewood, NJ      failed   4000.0     20.0
# 2               Animation    Los Angeles, CA        live  20000.0     56.0
# 3             Documentary    Los Angeles, CA  successful   6000.0   6535.0
# 4                 Fashion           Novi, MI      failed   3500.0      0.0
# 5              Short Film       Portland, OR  successful   3500.0   3582.0
# 6              Short Film    Collegedale, TN      failed   1000.0    280.0
# 7                 Fashion        Chicago, IL  successful   2000.0   2180.0
# 8                   Music        Chicago, IL  successful   1000.0   1125.0
# 9            Illustration        Chicago, IL  successful   7500.0   9836.0
# 10       Film &amp; Video      Nashville, TN        live   8000.0      0.0
# 11          Open Software                NaN  successful     99.0    145.0
# 12             Indie Rock        Ashland, OR  successful  20000.0  20138.0
# 13                  Dance       New York, NY      failed   1500.0     75.0
# 14                Fiction                NaN      failed   6500.0    765.0
# 15             Short Film        Chicago, IL  successful    250.0    310.0
# 16             Nonfiction     Washington, DC      failed  25000.0      0.0
# 17                Fiction         Gretna, NE        live   5000.0     50.0
# 18       Film &amp; Video          Boise, ID  successful   2000.0   2925.0
# 19                Fiction          Tampa, FL  successful   1500.0   3511.0
# 20                Theater         Austin, TX      failed   4000.0    175.0
# 21             Short Film    Los Angeles, CA        live   2000.0    110.0
# 22                  Music       New York, NY  successful   5000.0   6860.0
# 23                  Games         Denver, CO  successful    500.0   5536.0
# 24                  Games         Eugene, OR      failed    600.0    192.0
# 25       Film &amp; Video  San Francisco, CA  successful   7000.0   7030.0
# 26               Art Book       Portland, OR  successful   8750.0   8805.0
# 27                Theater       Portland, ME  successful   1500.0   1505.0
# 28              Animation        Chicago, IL      failed  30000.0   6596.0
# 29       Film &amp; Video     Taipei, Taiwan      failed  12000.0   1502.0
# ...                   ...                ...         ...      ...      ...
# 45927          Short Film                NaN      failed   7000.0    446.0
# 45928          Short Film                NaN      failed   7000.0    446.0
# 45929             Theater    Los Angeles, CA  successful   5000.0   5390.0
# 45930             Theater    Los Angeles, CA  successful   5000.0   5390.0
# 45931         Photography       Brooklyn, NY  successful   1200.0   1220.0
# 45932         Photography       Brooklyn, NY  successful   1200.0   1220.0
# 45933    Film &amp; Video        Burbank, CA      failed  10000.0    250.0
# 45934    Film &amp; Video        Burbank, CA      failed  10000.0    250.0
# 45935           Animation       Petaluma, CA      failed   7849.1    843.0
# 45936                Food      Las Vegas, NV      failed  10000.0    252.0
# 45937         Documentary   Santa Monica, CA      failed  50000.0    255.0
# 45938             Fashion    Los Angeles, CA  successful   3310.0   4400.0
# 45939          Public Art     Cincinnati, OH      failed   5000.0    298.0
# 45940            Painting        Chicago, IL      failed   8500.0   2661.0
# 45941     Children's Book       Lakewood, CO      failed   2000.0     52.0
# 45942      Product Design          Miami, FL      failed  25000.0  13151.0
# 45943         Documentary    Los Angeles, CA  successful  25000.0  31166.0
# 45944              Comics       New York, NY  successful   1200.0   1516.0
# 45945                Rock       Columbia, SC  successful   2000.0   2390.0
# 45946         Photography       Columbus, GA      failed  10000.0      0.0
# 45947         Photography         Dallas, TX      failed  25000.0   1614.0
# 45948           Webseries    Los Angeles, CA  successful    200.0    884.0
# 45949         Documentary        Chicago, IL      failed  25000.0   2400.0
# 45950      Narrative Film     Long Beach, CA      failed  39000.0  13494.0
# 45951          Publishing                NaN  successful    350.0    750.0
# 45952               Dance         Austin, TX  successful    500.0    601.0
# 45953             Hip-Hop    Los Angeles, CA      failed  10000.0     75.0
# 45954                Rock    Los Angeles, CA  successful  10000.0  10000.0
# 45955             Fiction     Vero Beach, FL      failed   2999.0    257.0
# 45956      Conceptual Art        Bozeman, MT  successful  18000.0  18758.0
#
#        funded percentage                                      reward levels  \
# 0               1.099524               $25,$50,$100,$250,$500,$1,000,$2,500
# 1               0.005000                                  $1,$5,$10,$25,$50
# 2               0.002800  $1,$10,$25,$40,$50,$100,$250,$1,000,$1,337,$9,001
# 3               1.089167  $1,$10,$25,$30,$50,$75,$85,$100,$110,$250,$500...
# 4               0.000000                         $10,$25,$50,$100,$150,$250
# 5               1.023331                   $5,$25,$50,$100,$250,$500,$1,000
# 6               0.280000                                $5,$10,$25,$50,$100
# 7               1.090000                  $10,$20,$50,$100,$250,$500,$1,000
# 8               1.125000  $5,$8,$10,$15,$20,$30,$50,$100,$120,$250,$500,...
# 9               1.311527    $1,$20,$35,$50,$60,$100,$110,$500,$1,000,$1,500
# 10              0.000000               $5,$10,$25,$50,$100,$200,$500,$1,000
# 11              1.464646                                                 $1
# 12              1.006911  $3,$10,$15,$20,$25,$50,$75,$100,$150,$200,$250...
# 13              0.050000                                  $10,$50,$100,$500
# 14              0.117692                       $5,$10,$25,$50,$75,$150,$300
# 15              1.240000                                 $1,$5,$15,$50,$150
# 16              0.000000                                   $10,$25,$50,$250
# 17              0.010000                                               $100
# 18              1.462500                            $10,$25,$50,$100,$1,000
# 19              2.340440                $5,$10,$25,$35,$50,$100,$250,$2,000
# 20              0.043750                           $25,$50,$100,$500,$1,000
# 21              0.055000       $1,$5,$10,$25,$50,$100,$250,$500,$750,$1,250
# 22              1.372000  $16,$20,$40,$45,$65,$100,$200,$400,$1,000,$1,2...
# 23             11.071740  $1,$5,$10,$25,$50,$75,$95,$100,$150,$200,$250,...
# 24              0.320217                            $1,$6,$12,$60,$120,$600
# 25              1.004286                        $25,$50,$100,$125,$250,$500
# 26              1.006286  $15,$25,$75,$100,$150,$200,$250,$495,$500,$850...
# 27              1.003333                            $15,$30,$90,$150,$1,000
# 28              0.219867  $5,$10,$20,$50,$100,$250,$500,$750,$1,500,$3,0...
# 29              0.125167                                                $10
# ...                  ...                                                ...
# 45927           0.063714                    $5,$10,$25,$50,$100,$500,$1,000
# 45928           0.063714                    $5,$10,$25,$50,$100,$500,$1,000
# 45929           1.078000               $1,$10,$25,$50,$100,$200,$500,$1,000
# 45930           1.078000               $1,$10,$25,$50,$100,$200,$500,$1,000
# 45931           1.016667                         $15,$25,$50,$100,$200,$500
# 45932           1.016667                         $15,$25,$50,$100,$200,$500
# 45933           0.025000  $10,$25,$50,$75,$100,$150,$250,$500,$1,000,$1,...
# 45934           0.025000  $10,$25,$50,$75,$100,$150,$250,$500,$1,000,$1,...
# 45935           0.107401                       $10,$35,$65,$125,$475,$1,000
# 45936           0.025200  $1,$10,$25,$50,$75,$100,$100,$125,$150,$150,$1...
# 45937           0.005100              $1,$25,$51,$251,$1,000,$5,000,$10,000
# 45938           1.329305           $1,$10,$20,$35,$50,$100,$200,$500,$1,000
# 45939           0.059600                                   $10,$25,$50,$100
# 45940           0.313059  $1,$5,$10,$20,$45,$65,$85,$90,$135,$170,$250,$...
# 45941           0.026000                              $1,$50,$100,$200,$500
# 45942           0.526040  $1,$25,$65,$125,$190,$275,$500,$2,500,$5,000,$...
# 45943           1.246633  $1,$5,$10,$25,$25,$35,$50,$60,$75,$100,$125,$1...
# 45944           1.263725  $5,$7,$10,$14,$15,$20,$24,$25,$40,$50,$70,$75,...
# 45945           1.195000  $20,$30,$40,$50,$75,$100,$250,$300,$500,$750,$...
# 45946           0.000000                       $1,$10,$25,$60,$80,$100,$250
# 45947           0.064560  $1,$5,$10,$25,$50,$100,$150,$200,$500,$1,000,$...
# 45948           4.420000  $2,$5,$6,$8,$9,$10,$15,$20,$25,$30,$40,$50,$75...
# 45949           0.096000                      $25,$50,$100,$250,$500,$1,500
# 45950           0.346000  $1,$25,$25,$50,$50,$75,$100,$250,$500,$1,000,$...
# 45951           2.142857                                                NaN
# 45952           1.202000                                       $20,$50,$100
# 45953           0.007500  $1,$5,$10,$25,$50,$50,$75,$100,$200,$250,$500,...
# 45954           1.000000                                  $10,$25,$100,$500
# 45955           0.085695                        $15,$16,$19,$29,$29,$39,$75
# 45956           1.042111  $25,$25,$50,$100,$125,$250,$500,$1,250,$2,500,...
#
#        updates  comments  duration weekday  weekday_nr month  month_nr  year  \
# 0           10         2     30.00     Fri           5   Aug         8  2011
# 1            6         0     47.18     Mon           1   Aug         8  2010
# 2            1         0     28.00     Fri           5   Jun         6  2012
# 3            4         0     32.22     Sun           7   Apr         4  2012
# 4            2         0     30.00     Wed           3   Jun         6  2011
# 5            8         0     21.43     Wed           3   Jun         6  2011
# 6            0         0     30.00     Sat           6   Feb         2  2012
# 7           13         5     30.00     Fri           5   Dec        12  2011
# 8           10         1     67.53     Sun           7   Apr         4  2010
# 9            6         5     35.29     Tue           2   Nov        11  2011
# 10           0         0     38.20     Sun           7   Jul         7  2012
# 11           5        19     79.64     Tue           2   Jul         7  2009
# 12           8        12     45.04     Fri           5   Dec        12  2010
# 13           0         0     40.04     Sun           7   Dec        12  2010
# 14          10         0     60.34     Fri           5   Jul         7  2010
# 15           2         0     30.00     Wed           3   Jul         7  2011
# 16           0         0     29.96     Sat           6   Mar         3  2012
# 17           0         0     30.00     Sat           6   Jun         6  2012
# 18           2         0     31.04     Fri           5   Dec        12  2010
# 19          31         7     21.00     Mon           1   Mar         3  2012
# 20           2         0     60.00     Sat           6   Nov        11  2011
# 21           1         1     30.30     Sun           7   Jul         7  2012
# 22          28         9     88.19     Thu           4   Nov        11  2009
# 23          36        36     25.94     Mon           1   Apr         4  2012
# 24           0         0     60.00     Mon           1   Oct        10  2011
# 25           0         0     37.34     Mon           1   Oct        10  2010
# 26          12        12     60.00     Tue           2   Jan         1  2012
# 27           1         0     42.96     Tue           2   Jan         1  2012
# 28           4         5     60.00     Thu           4   Sep         9  2011
# 29           1         0     45.00     Sun           7   May         5  2011
# ...        ...       ...       ...     ...         ...   ...       ...   ...
# 45927        1         0     60.99     Sun           7   Oct        10  2010
# 45928        1         0     60.99     Sun           7   Oct        10  2010
# 45929        5         1     30.00     Sat           6   Jun         6  2011
# 45930        5         1     30.00     Sat           6   Jun         6  2011
# 45931        1         0     30.00     Thu           4   Mar         3  2011
# 45932        1         0     30.00     Thu           4   Mar         3  2011
# 45933        0         0     60.00     Sat           6   Sep         9  2011
# 45934        0         0     60.00     Sat           6   Sep         9  2011
# 45935        0         0     32.47     Fri           5   Sep         9  2011
# 45936        0         0     59.96     Sat           6   Mar         3  2012
# 45937        0         0     60.04     Mon           1   Dec        12  2011
# 45938       10         2     30.00     Fri           5   Aug         8  2011
# 45939        0         0     25.70     Mon           1   Apr         4  2012
# 45940        1         0     14.84     Thu           4   Mar         3  2012
# 45941        0         0     60.00     Sun           7   Feb         2  2012
# 45942       10        29     50.00     Sat           6   Aug         8  2011
# 45943       14        35     33.65     Sun           7   Aug         8  2011
# 45944        0         1     36.18     Thu           4   Dec        12  2011
# 45945        1         0     57.57     Sat           6   Jan         1  2011
# 45946        1         0     60.00     Fri           5   Feb         2  2011
# 45947        0         3     37.00     Fri           5   Dec        12  2011
# 45948        5         0     90.00     Thu           4   Jun         6  2011
# 45949        5         7     35.00     Mon           1   Aug         8  2011
# 45950        5        10     41.68     Mon           1   Nov        11  2010
# 45951        3        10     61.99     Wed           3   Jul         7  2009
# 45952        2         0     37.83     Fri           5   Mar         3  2012
# 45953        1         1     59.96     Sun           7   Apr         4  2012
# 45954        2         0     27.32     Mon           1   Jan         1  2012
# 45955       17         0     30.00     Sat           6   May         5  2012
# 45956       20         4     40.38     Thu           4   Aug         8  2011
#
#                  time
# 0      19:28:17 -0000
# 1      03:59:00 -0000
# 2      00:00:31 -0000
# 3      02:14:00 -0000
# 4      15:25:39 -0000
# 5      13:33:00 -0000
# 6      02:17:08 -0000
# 7      04:36:53 -0000
# 8      04:59:00 -0000
# 9      04:59:00 -0000
# 10     04:11:00 -0000
# 11     06:59:59 -0000
# 12     20:00:07 -0000
# 13     02:09:39 -0000
# 14     03:59:00 -0000
# 15     22:46:51 -0000
# 16     23:31:04 -0000
# 17     22:57:28 -0000
# 18     04:49:06 -0000
# 19     15:43:00 -0000
# 20     00:17:23 -0000
# 21     03:00:00 -0000
# 22     18:38:00 -0000
# 23     03:59:00 -0000
# 24     18:20:52 -0000
# 25     06:59:00 -0000
# 26     00:16:42 -0000
# 27     20:00:00 -0000
# 28     00:05:37 -0000
# 29     05:15:04 -0000
# ...               ...
# 45927  04:00:00 -0000
# 45928  04:00:00 -0000
# 45929  08:56:58 -0000
# 45930  08:56:58 -0000
# 45931  04:09:38 -0000
# 45932  04:09:38 -0000
# 45933  19:00:47 -0000
# 45934  19:00:47 -0000
# 45935  07:00:00 -0000
# 45936  01:46:13 -0000
# 45937  23:15:47 -0000
# 45938  03:28:27 -0000
# 45939  22:44:00 -0000
# 45940  05:59:00 -0000
# 45941  17:20:59 -0000
# 45942  14:42:08 -0000
# 45943  06:00:00 -0000
# 45944  05:00:00 -0000
# 45945  04:59:00 -0000
# 45946  00:16:50 -0000
# 45947  04:00:00 -0000
# 45948  18:37:03 -0000
# 45949  15:55:40 -0000
# 45950  17:00:00 -0000
# 45951  05:00:00 -0000
# 45952  13:57:00 -0000
# 45953  02:12:10 -0000
# 45954  05:00:00 -0000
# 45955  19:44:47 -0000
# 45956  04:30:00 -0000
#
# [45957 rows x 20 columns]

# %% [markdown]
# ### name column: Turn all letters to lower case

# %%
data['name'] = data['name'].str.lower()
data.head(3)
# Out:
#    project id                                  name  \
# 0       39409                 while the trees sleep
# 1      126581  educational online trading card game
# 2      138119                                 strum
#
#                                                  url      category  \
# 0  http://www.kickstarter.com/projects/emiliesaba...  Film & Video
# 1  http://www.kickstarter.com/projects/972789543/...         Games
# 2  http://www.kickstarter.com/projects/185476022/...  Film & Video
#
#           subcategory         location      status     goal  pledged  \
# 0          Short Film     Columbia, MO  successful  10500.0  11545.0
# 1  Board & Card Games    Maplewood, NJ      failed   4000.0     20.0
# 2           Animation  Los Angeles, CA        live  20000.0     56.0
#
#    funded percentage  backers                      funded date  levels  \
# 0           1.099524       66  Fri, 19 Aug 2011 19:28:17 -0000       7
# 1           0.005000        2  Mon, 02 Aug 2010 03:59:00 -0000       5
# 2           0.002800        3  Fri, 08 Jun 2012 00:00:31 -0000      10
#
#                                        reward levels  updates  comments  \
# 0               $25,$50,$100,$250,$500,$1,000,$2,500       10         2
# 1                                  $1,$5,$10,$25,$50        6         0
# 2  $1,$10,$25,$40,$50,$100,$250,$1,000,$1,337,$9,001        1         0
#
#    duration
# 0     30.00
# 1     47.18
# 2     28.00

# %% [markdown]
# ## Was the initial findings in themself correct?

# %% [markdown]
# #### Best lenght for compaign?
# more then $6,000 - 35 days
#
# less then $6,000 - a shorter duration is better

# %% [markdown]
# #### Different pledge goals at low and high amonts
# But for both intervals a low pledge seem to me more successful. (No surprise)

# %% [markdown]
# #### Some types of campaign are more successful than others
# <u>Category</u>
#
# Dance, theater, music (most successfull)
#
# Fashion, publishing, technology (fashion is by far least successfull)
#
#
# <u>Sub categorys of the Music category</u>
#
# Indie rock, country & folk, jazz, Classical music (most successfull)
#
# Hip hop, electronic music, world music (Hip hop is by far least successfull)
#
#
# #### When to launch?
#
# Month: February
#
# Day: Monday
#
# Time: 9:00 am (EST)
#
# (The variables was studied individually, this means that a Monday in February at 9:00 am might not necessarily be the best time.)
#
# #### More comments, more success
#
# Dubble the successrate with 1-2 comments
#
# Tripple the successrate with 10 comments
